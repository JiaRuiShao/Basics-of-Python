# %%
import pandas as pd
from pandas import DataFrame, Series
import datetime as dt

# %%
df4=pd.read_csv('311OneDay.csv')
df4.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    37777723  11/26/2017 12:00:01 AM                     NaN   NYPD
# 1    37780103  11/26/2017 12:01:40 AM                     NaN  CHALL
# 2    37780960  11/26/2017 12:01:41 AM                     NaN   NYPD
# 3    37777917  11/26/2017 12:01:51 AM  11/26/2017 01:28:28 AM   NYPD
# 4    37782315  11/26/2017 12:01:53 AM  11/26/2017 12:52:29 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department         Derelict Vehicle
# 1                            CHALL    Opinion for the Mayor
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department  Noise - Street/Sidewalk
# 4  New York City Police Department      Noise - Residential
#
#            Descriptor               Location Type  Incident Zip  \
# 0  With License Plate             Street/Sidewalk       11423.0
# ...

# %%
dd=DataFrame(df4.groupby(['Agency', 'Complaint Type']).size())
dd.columns=['Count']
dd2=dd.reset_index()
dd3=dd2.sort_values(by=['Agency', 'Count','Complaint Type'],ascending=False)
dd3
# Out:
#    Agency                       Complaint Type  Count
# 26    TLC                       Taxi Complaint      3
# 25    TLC           For Hire Vehicle Complaint      1
# 20   NYPD                  Noise - Residential    253
# 17   NYPD                   Noise - Commercial     68
# 21   NYPD              Noise - Street/Sidewalk     48
# 13   NYPD                     Blocked Driveway     31
# 16   NYPD                      Illegal Parking     21
# 22   NYPD                      Noise - Vehicle     12
# 14   NYPD                     Derelict Vehicle      4
# 23   NYPD          Non-Emergency Police Matter      2
# 15   NYPD                  Homeless Encampment      2
# 24   NYPD                              Traffic      1
# 19   NYPD                         Noise - Park      1
# 18   NYPD             Noise - House of Worship      1
# 12    HRA             Benefit Card Replacement      1
# 11    HPD                       HEAT/HOT WATER      1
# ...

# %%
dd3.groupby(['Agency'],as_index=False).head(2)
# Out:
#    Agency                       Complaint Type  Count
# 26    TLC                       Taxi Complaint      3
# 25    TLC           For Hire Vehicle Complaint      1
# 20   NYPD                  Noise - Residential    253
# 17   NYPD                   Noise - Commercial     68
# 12    HRA             Benefit Card Replacement      1
# 11    HPD                       HEAT/HOT WATER      1
# 10   DSNY  Request Large Bulky Item Collection      8
# 7     DOT                     Street Condition      5
# 8     DOT               Street Light Condition      3
# 5   DOHMH                               Rodent      3
# 4   DOHMH                   Food Establishment      2
# 3     DOF               DOF Literature Request      1
# 2     DHS           Homeless Person Assistance      4
# 1     DCA                   Consumer Complaint      2
# 0   CHALL                Opinion for the Mayor      1
